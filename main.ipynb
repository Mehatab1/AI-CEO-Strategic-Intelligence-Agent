# %% [markdown]
# # Main Pipeline
#
# Runs the whole project from start to finish, in order:
#
# 1. Collect data (SAP News, GNews, Hacker News)
# 2. Clean the data
# 3. Build embeddings + FAISS index
# 4. Run the opportunity, risk, trend, and competitor agents
# 5. Run the CEO agent
#
# After this notebook finishes, run `streamlit run app.py` to see the dashboard.
#
# Before running this, make sure Ollama is installed and running:
# ```
# bash setup.sh
# ollama list
# ```

# %%
import subprocess
import time

# nbconvert default timeout is 60 sec, way too short for embedding/LLM steps
TIMEOUT = 3600  # 1 hour per notebook - local CPU LLM calls can each take up to 15 min


def run_notebook(path):
    print("Running:", path)
    start = time.time()

    subprocess.run([
        "jupyter", "nbconvert",
        "--to", "notebook",
        "--execute",
        "--inplace",
        f"--ExecutePreprocessor.timeout={TIMEOUT}",
        path,
    ], check=True)

    minutes = (time.time() - start) / 60
    print(f"Done: {path}  ({minutes:.1f} min)")
    print()

# %% [markdown]
# ## Step 1: Collect data

# %%
collection_notebooks = [
    "01_Data_Collection_cleaned/01_sap_news.ipynb",
    "01_Data_Collection_cleaned/02_gnew.ipynb",
    "01_Data_Collection_cleaned/03_hackernews.ipynb",
]

for nb_path in collection_notebooks:
    run_notebook(nb_path)
# Out:
# Running: 01_Data_Collection_cleaned/01_sap_news.ipynb
# [NbConvertApp] Converting notebook 01_Data_Collection_cleaned/01_sap_news.ipynb to notebook
# [NbConvertApp] Writing 5551 bytes to 01_Data_Collection_cleaned/01_sap_news.ipynb
# Done: 01_Data_Collection_cleaned/01_sap_news.ipynb  (0.2 min)
#
# Running: 01_Data_Collection_cleaned/02_gnew.ipynb
# [NbConvertApp] Converting notebook 01_Data_Collection_cleaned/02_gnew.ipynb to notebook
# [NbConvertApp] Writing 12190 bytes to 01_Data_Collection_cleaned/02_gnew.ipynb
# Done: 01_Data_Collection_cleaned/02_gnew.ipynb  (0.6 min)
#
# Running: 01_Data_Collection_cleaned/03_hackernews.ipynb
# [NbConvertApp] Converting notebook 01_Data_Collection_cleaned/03_hackernews.ipynb to notebook
# [NbConvertApp] Writing 5289 bytes to 01_Data_Collection_cleaned/03_hackernews.ipynb
# Done: 01_Data_Collection_cleaned/03_hackernews.ipynb  (0.1 min)

# %% [markdown]
# ## Step 2: Clean the data

# %%
run_notebook("notebook/data_cleaning.ipynb")
# Out:
# Running: notebook/data_cleaning.ipynb
# [NbConvertApp] Converting notebook notebook/data_cleaning.ipynb to notebook
# [NbConvertApp] Writing 26293 bytes to notebook/data_cleaning.ipynb
# Done: notebook/data_cleaning.ipynb  (0.0 min)

# %% [markdown]
# ## Step 3: Build embeddings + FAISS index

# %%
run_notebook("notebook/embedding_v2.ipynb")
# Out:
# Running: notebook/embedding_v2.ipynb
# [NbConvertApp] Converting notebook notebook/embedding_v2.ipynb to notebook
# [NbConvertApp] Writing 44870 bytes to notebook/embedding_v2.ipynb
# Done: notebook/embedding_v2.ipynb  (0.2 min)

# %% [markdown]
# ## Step 4: Run the strategic intelligence agents

# %%
agent_notebooks = [
    "agents/01_opportunity_agent.ipynb",
    "agents/02_risk_agent.ipynb",
    "agents/03_trend_agent.ipynb",
    "agents/04_competitor_monitor.ipynb",
]

for nb_path in agent_notebooks:
    run_notebook(nb_path)
# Out:
# Running: agents/01_opportunity_agent.ipynb
# [NbConvertApp] Converting notebook agents/01_opportunity_agent.ipynb to notebook
# [NbConvertApp] Writing 31437 bytes to agents/01_opportunity_agent.ipynb
# Done: agents/01_opportunity_agent.ipynb  (0.4 min)
#
# Running: agents/02_risk_agent.ipynb
# [NbConvertApp] Converting notebook agents/02_risk_agent.ipynb to notebook
# [NbConvertApp] Writing 29602 bytes to agents/02_risk_agent.ipynb
# Done: agents/02_risk_agent.ipynb  (0.3 min)
#
# Running: agents/03_trend_agent.ipynb
# [NbConvertApp] Converting notebook agents/03_trend_agent.ipynb to notebook
# [NbConvertApp] Writing 30789 bytes to agents/03_trend_agent.ipynb
# Done: agents/03_trend_agent.ipynb  (0.4 min)
#
# Running: agents/04_competitor_monitor.ipynb
# [NbConvertApp] Converting notebook agents/04_competitor_monitor.ipynb to notebook
# Done: agents/04_competitor_monitor.ipynb  (0.4 min)
# [NbConvertApp] Writing 35576 bytes to agents/04_competitor_monitor.ipynb

# %% [markdown]
# ## Step 5: Run the CEO agent

# %%
run_notebook("agents/05_ceo_agent.ipynb")
# Out:
# Running: agents/05_ceo_agent.ipynb
# [NbConvertApp] Converting notebook agents/05_ceo_agent.ipynb to notebook
# [NbConvertApp] Writing 16248 bytes to agents/05_ceo_agent.ipynb
# Done: agents/05_ceo_agent.ipynb  (0.1 min)

# %% [markdown]
# ## Done
#
# All the data files needed by the dashboard should now be in `notebook/data/`:
# - `clean_data.json`
# - `chunked_data.json`, `chunk_embeddings.npy`, `sap_intelligence.index`
# - `opportunities.json`, `risks.json`, `trends.json`, `competitor_activity.json`
# - `recommendations.json`, `ceo_briefing.json`
#
# Run the dashboard with:
# ```
# streamlit run app.py
# ```

# %%
import os

data_dir = "notebook/data"
expected_files = [
    "clean_data.json",
    "chunked_data.json",
    "chunk_embeddings.npy",
    "sap_intelligence.index",
    "opportunities.json",
    "risks.json",
    "trends.json",
    "competitor_activity.json",
    "recommendations.json",
    "ceo_briefing.json",
]

print("Checking output files:")
for f in expected_files:
    path = os.path.join(data_dir, f)
    exists = os.path.exists(path)
    print(f"  [{'OK' if exists else 'MISSING'}] {f}")
# Out:
# Checking output files:
#   [OK] clean_data.json
#   [OK] chunked_data.json
#   [OK] chunk_embeddings.npy
#   [OK] sap_intelligence.index
#   [OK] opportunities.json
#   [OK] risks.json
#   [OK] trends.json
#   [OK] competitor_activity.json
#   [OK] recommendations.json
#   [OK] ceo_briefing.json
